# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaaaddddyyyyyyyy/Keras/blob/main/Keras_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/Bank_Churn.csv')

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.drop(columns=['CustomerId','Surname'])
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df['Geography']=encoder.fit_transform(df['Geography'])
df['Gender']=encoder.fit_transform(df['Gender'])

# %%
df.drop(columns=['CustomerId','Surname'])
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
df= pd.get_dummies(df,columns=['Geography'],drop_first=True)

# %%
df
# Out:
#       CustomerId    Surname  CreditScore  Gender  Age  Tenure    Balance  \
# 0       15634602   Hargrave          619       0   42       2       0.00
# 1       15647311       Hill          608       0   41       1   83807.86
# 2       15619304       Onio          502       0   42       8  159660.80
# 3       15701354       Boni          699       0   39       1       0.00
# 4       15737888   Mitchell          850       0   43       2  125510.82
# ...          ...        ...          ...     ...  ...     ...        ...
# 9995    15606229   Obijiaku          771       1   39       5       0.00
# 9996    15569892  Johnstone          516       1   35      10   57369.61
# 9997    15584532        Liu          709       0   36       7       0.00
# 9998    15682355  Sabbatini          772       1   42       3   75075.31
# 9999    15628319     Walker          792       0   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# ...

# %%
X=df.drop(columns=['Exited'],axis=1).values
y=df['Exited'].values

# %%
X
# Out:
# array([[15634602, 'Hargrave', 619, ..., 101348.88, False, False],
#        [15647311, 'Hill', 608, ..., 112542.58, False, True],
#        [15619304, 'Onio', 502, ..., 113931.57, False, False],
#        ...,
#        [15584532, 'Liu', 709, ..., 42085.58, False, False],
#        [15682355, 'Sabbatini', 772, ..., 92888.52, True, False],
#        [15628319, 'Walker', 792, ..., 38190.78, False, False]],
#       dtype=object)

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
df.drop(columns=['Surname'],axis=1)
# Out:
#       CustomerId  CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0       15634602          619       0   42       2       0.00              1
# 1       15647311          608       0   41       1   83807.86              1
# 2       15619304          502       0   42       8  159660.80              3
# 3       15701354          699       0   39       1       0.00              2
# 4       15737888          850       0   43       2  125510.82              1
# ...          ...          ...     ...  ...     ...        ...            ...
# 9995    15606229          771       1   39       5       0.00              2
# 9996    15569892          516       1   35      10   57369.61              1
# 9997    15584532          709       0   36       7       0.00              1
# 9998    15682355          772       1   42       3   75075.31              2
# 9999    15628319          792       0   28       4  130142.79              1
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=32)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

# %%
X.shape
# Out:
# (10000, 13)

# %%
model.add(Dense(11,activation='relu',input_dim=X_train.shape[1]))
model.add(Dense(11,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           154 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            12 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 430 (1.68 KB)
#  Trainable params: 430 (1.68 KB)
#  Non-trainable params: 0 (0.00 B)
